# %%
from tensorflow.keras.layers import Input , Lambda , Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50 , preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator , load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob 
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\patel1637\AppData\Local\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
import cv2

from keras.preprocessing import image
from keras.preprocessing.image import load_img , img_to_array
import numpy as np

# %%
import os

categories = ['nonpit','pit']


def preprareImage(PathForImage):
    image = load_img(PathForImage, target_size=(1280,1280))
    imgResult = img_to_array(image)
    imgResult = np.expand_dims(imgResult, axis = 0)
    imgResult = imgResult / 255.
    return imgResult

model = tf.keras.models.load_model('C:/Python-cannot-upload-to-GitHub/Cars/myPitsModel.h5')


# Path to the directory containing allnonpits images
folder_path = "C:/Users/patel1637/AddNonPitSmall"

# List all files in the directory
image_files = os.listdir(folder_path)

# Loop through each image file
for image_file in image_files:
    # Construct the full path for the image
    image_path = os.path.join(folder_path, image_file)
    
    # Prepare the image for prediction
    imgForModel = preprareImage(image_path)
    
    # Predict using the model
    resultArray = model.predict(imgForModel, verbose=1)
    
    # Get the predicted category
    answer = np.argmax(resultArray, axis=1)
    index = answer[0]
    
    # Print the predicted category
    print("***************************** : ")
    print("Image:", image_file)
    print("Predicted category:", categories[index])
    print("***************************** : ")
# Out:
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Image: pitImage_49.0582241_-113.7150728.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_49.1865802_-113.7309784.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_49.187687_-113.733499.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_49.1931795_-113.9964296.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7507676_-110.5989456.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7508083_-110.9757386.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7511183_-110.6327079.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7511405_-110.6093397.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7511452_-110.9359778.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7514814_-110.8064397.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7516084_-114.3620685.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7521018_-110.5660134.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7521364_-114.3689824.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7527786_-110.9551278.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7529092_-110.7343783.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7534493_-110.7772558.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7539651_-110.502382.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.754162_-110.516789.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7553957_-110.8739519.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7558483_-114.3622548.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7588314_-110.9888215.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7591867_-114.3574942.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.759361_-114.3621407.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7599736_-110.9414247.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7600313_-110.6890941.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7600944_-110.9976392.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7603859_-110.8179788.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7606109_-110.5130282.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7610444_-110.8385094.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7610545_-110.5475729.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7611286_-110.6988708.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7612471_-110.7673467.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7613277_-110.6638966.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7626005_-114.3681566.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7629184_-114.3627067.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7652098_-110.5757483.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7652504_-110.5982493.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7657986_-110.6681547.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7658289_-114.367947.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7666623_-114.3635745.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7667545_-110.9874342.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7675355_-110.6056517.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7679581_-110.6864299.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7684961_-110.5022287.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7735672_-114.3795605.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7751841_-110.6174546.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7754882_-110.6060267.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7756702_-110.5940656.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7773165_-114.3966646.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7773754_-114.3911883.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 1s 1s/step
# ***************************** :
# Image: pitImage_50.7775333_-114.3856416.png
# Predicted category: pit
# ***************************** :
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\PIL\ImageFile.py:249, in ImageFile.load(self)
#     248 try:
# --> 249     s = read(self.decodermaxblock)
#     250 except (IndexError, struct.error) as e:
#     251     # truncated png/gif
#
# File ~\AppData\Local\anaconda3\lib\site-packages\PIL\PngImagePlugin.py:957, in PngImageFile.load_read(self, read_bytes)
#     955 self.fp.read(4)  # CRC
# --> 957 cid, pos, length = self.png.read()
#     959 if cid not in [b"IDAT", b"DDAT", b"fdAT"]:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\PIL\PngImagePlugin.py:179, in ChunkStream.read(self)
#     178     pos = self.fp.tell()
# --> 179     length = i32(s)
#     181 if not is_cid(cid):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\PIL\_binary.py:85, in i32be(c, o)
#      84 def i32be(c, o=0):
# ---> 85     return unpack_from(">I", c, o)[0]
#
# error: unpack_from requires a buffer of at least 4 bytes for unpacking 4 bytes at offset 0 (actual buffer size is 0)
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 28
#      25 image_path = os.path.join(folder_path, image_file)
#      27 # Prepare the image for prediction
# ---> 28 imgForModel = preprareImage(image_path)
#      30 # Predict using the model
#      31 resultArray = model.predict(imgForModel, verbose=1)
#
# Cell In[13], line 8, in preprareImage(PathForImage)
#       6 def preprareImage(PathForImage):
#       7     image = load_img(PathForImage, target_size=(1280,1280))
# ----> 8     imgResult = img_to_array(image)
#       9     imgResult = np.expand_dims(imgResult, axis = 0)
#      10     imgResult = imgResult / 255.
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\src\utils\image_utils.py:324, in img_to_array(img, data_format, dtype)
#     320     raise ValueError(f"Unknown data_format: {data_format}")
#     321 # Numpy array x has format (height, width, channel)
#     322 # or (channel, height, width)
#     323 # but original PIL image has format (width, height, channel)
# --> 324 x = np.asarray(img, dtype=dtype)
#     325 if len(x.shape) == 3:
#     326     if data_format == "channels_first":
#
# File ~\AppData\Local\anaconda3\lib\site-packages\PIL\Image.py:701, in Image.__array_interface__(self)
#     699         new["data"] = self.tobytes("raw", "L")
#     700     else:
# --> 701         new["data"] = self.tobytes()
#     702 except Exception as e:
#     703     if not isinstance(e, (MemoryError, RecursionError)):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\PIL\Image.py:758, in Image.tobytes(self, encoder_name, *args)
#     755 if encoder_name == "raw" and args == ():
#     756     args = self.mode
# --> 758 self.load()
#     760 if self.width == 0 or self.height == 0:
#     761     return b""
#
# File ~\AppData\Local\anaconda3\lib\site-packages\PIL\ImageFile.py:256, in ImageFile.load(self)
#     254     else:
#     255         msg = "image file is truncated"
# --> 256         raise OSError(msg) from e
#     258 if not s:  # truncated jpeg
#     259     if LOAD_TRUNCATED_IMAGES:
#
# OSError: image file is truncated

# %%
import os

categories = ['nonpit','pit']


def preprareImage(PathForImage):
    image = load_img(PathForImage, target_size=(1280,1280))
    imgResult = img_to_array(image)
    imgResult = np.expand_dims(imgResult, axis = 0)
    imgResult = imgResult / 255.
    return imgResult

model = tf.keras.models.load_model('C:/Python-cannot-upload-to-GitHub/Cars/myPitsModel.h5')


# Path to the directory containing allnonpits images
folder_path = "C:/Users/patel1637/AddNonPitSmall"

# List all files in the directory
image_files = os.listdir(folder_path)

skip_count = 0

# Loop through each image file
for ind, image_file in enumerate(image_files):
    if skip_count < 100:
        skip_count += 1
        continue
    # Construct the full path for the image
    image_path = os.path.join(folder_path, image_file)
    
    # Prepare the image for prediction
    imgForModel = preprareImage(image_path)
    
    # Predict using the model
    resultArray = model.predict(imgForModel, verbose=1)
    
    # Get the predicted category
    answer = np.argmax(resultArray, axis=1)
    index = answer[0]
    
    # Print the predicted category
    print("***************************** : ")
    print("Processing image index:", ind)
    print("Image:", image_file)
    print("Predicted category:", categories[index])
    print("***************************** : ")
# Out:
# 1/1 [==============================] - 3s 3s/step
# ***************************** :
# Processing image index: 100
# Image: pitImage_50.811963_-110.5516446.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index:
png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 374
# Image: pitImage_51.2974033_-112.7483096.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 375
# Image: pitImage_51.2982438_-112.7389037.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 376
# Image: pitImage_51.2999346_-112.9354037.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 377
# Image: pitImage_51.3014962_-112.8268234.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 378
# Image: pitImage_51.302094_-112.7331577.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 379
# Image: pitImage_51.3021922_-112.7406471.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 380
# Image: pitImage_51.3026213_-112.7574179.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 381
# Image: pitImage_51.3031227_-112.727371.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 382
# Image: pitImage_51.3034573_-112.7232977.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 383
# Image: pitImage_51.3050841_-112.8491615.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 384
# Image: pitImage_51.3051568_-112.7324808.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 385
# Image: pitImage_51.3057544_-112.7363485.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 386
# Image: pitImage_51.3057931_-112.7275674.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 387
# Image: pitImage_51.305802_-112.7579249.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 3s 3s/step
# ***************************** :
# Processing image index: 388
# Image: pitImage_51.30615_-112.5281727.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 389
# Image: pitImage_51.306407_-112.7819852.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 390
# Image: pitImage_51.3069547_-112.7625287.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 391
# Image: pitImage_51.3088187_-112.8262287.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 392
# Image: pitImage_51.3089246_-112.6680118.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 393
# Image: pitImage_51.3094198_-112.727689.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 394
# Image: pitImage_51.3106196_-112.7463784.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 395
# Image: pitImage_51.3106511_-112.7534483.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 396
# Image: pitImage_51.312323_-112.7459234.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 397
# Image: pitImage_51.3128337_-112.7270515.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 398
# Image: pitImage_51.3130784_-112.7335717.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 399
# Image: pitImage_51.3132353_-112.6854942.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 400
# Image: pitImage_51.3159768_-112.7334965.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 401
# Image: pitImage_51.3169246_-112.7280018.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 402
# Image: pitImage_51.319644_-112.855347.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 403
# Image: pitImage_51.3196972_-112.8315419.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 404
# Image: pitImage_51.3199129_-112.7391465.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 405
# Image: pitImage_51.3199517_-112.6681715.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 406
# Image: pitImage_51.3199733_-112.6397544.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 407
# Image: pitImage_51.3200957_-112.8091922.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 408
# Image: pitImage_51.3203374_-112.7273186.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 409
# Image: pitImage_51.3214239_-112.7465932.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 410
# Image: pitImage_51.3219389_-112.875268.png
# Predicted category: pit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 411
# Image: pitImage_51.3235526_-112.7444515.png
# Predicted category: nonpit
# ***************************** :
# 1/1 [==============================] - 2s 2s/step
# ***************************** :
# Processing image index: 412
# Image: pitImage_51.3276072_-112.7395631.png
# Predicted category: nonpit
# ***************************** :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 36
#      33 imgForModel = preprareImage(image_path)
#      35 # Predict using the model
# ---> 36 resultArray = model.predict(imgForModel, verbose=1)
#      38 # Get the predicted category
#      39 answer = np.argmax(resultArray, axis=1)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\src\engine\training.py:2655, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2653 for step in data_handler.steps():
#    2654     callbacks.on_predict_batch_begin(step)
# -> 2655     tmp_batch_outputs = self.predict_function(iterator)
#    2656     if data_handler.should_sync:
#    2657         context.async_wait()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:877, in Function._call(self, *args, **kwds)
#     874 self._lock.release()
#     875 # In this case we have not created variables on the first call. So we can
#     876 # run the first trace but we should fail if variables are created.
# --> 877 results = tracing_compilation.call_function(
#     878     args, kwds, self._variable_creation_config
#     879 )
#     880 if self._created_variables:
#     881   raise ValueError("Creating variables on a non-first call to a function"
#     882                    " decorated with tf.function.")
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
